# %% [markdown]
# # example code

# %%
# https://www.codingfinance.com/post/2018-04-03-calc-returns-py/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web
import yfinance as yf
import csv
# Out:
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:9: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ## single stock

# %%
# download (netflix) stock price from yahoo finance
netflix = web.get_data_yahoo("NFLX",
                            start = "2009-01-01",
                            end = "2018-03-01")
print(netflix.head())

# %%
# chart the adjusted closing price
netflix['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Netflix Price data")
plt.show()

# %%
# calculate daily & monthly returns for individual stock
netflix_daily_returns = netflix['Adj Close'].pct_change()
netflix_monthly_returns = netflix['Adj Close'].resample('M').ffill().pct_change()
print(netflix_daily_returns.head())
print(netflix_monthly_returns.head())

# %%
# charting the daily  
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(netflix_daily_returns)
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("Netflix daily returns data")
plt.show()

# %%
# charting the monthly
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(netflix_monthly_returns)
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("Netflix monthly returns data")
plt.show()

# %%
# histogram
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
netflix_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("Netflix daily returns data")
ax1.text(-0.35,200,"Extreme Low\nreturns")
ax1.text(0.25,200,"Extreme High\nreturns")
plt.show()

# %%
# calculating the cumulative (total) returns 
netflix_cum_returns = (netflix_daily_returns + 1).cumprod()

# %%
# chart the cumulative returns, daily
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
netflix_cum_returns.plot()
ax1.set_xlabel("Date")
ax1.set_ylabel("Growth of $1 investment")
ax1.set_title("Netflix daily cumulative returns data")
plt.show()

# %%
# chart the cumulative returns, monthly
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
netflix_cum_returns = (netflix_monthly_returns + 1).cumprod()
ax1.plot(netflix_cum_returns)
ax1.set_xlabel("Date")
ax1.set_ylabel("Growth of $1 investment")
ax1.set_title("Netflix Monthly cumulative returns data")
plt.show()

# %% [markdown]
# ## multiple stocks

# %%
# download from yahoo finance
tickers = ["FB", "AMZN", "AAPL", "NFLX", "GOOG"]
multpl_stocks = web.get_data_yahoo(tickers,start = "2013-01-01",end = "2018-03-01")

# %%
# charting the stock prices for multiple stocks
fig = plt.figure()
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax1.plot(multpl_stocks['Adj Close']['AMZN'])
ax1.set_title("Amazon")
ax2.plot(multpl_stocks['Adj Close']['AAPL'])
ax2.set_title("Apple")
ax3.plot(multpl_stocks['Adj Close']['FB'])
ax3.set_title("Facebook")
ax4.plot(multpl_stocks['Adj Close']['NFLX'])
ax4.set_title("Netflix")
ax5.plot(multpl_stocks['Adj Close']['GOOG'])
ax5.set_title("Google")
plt.tight_layout()
plt.show()

# %%
# calculating the returns for multiple stocks
multpl_stock_daily_returns = multpl_stocks['Adj Close'].pct_change()
multpl_stock_monthly_returns = multpl_stocks['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(multpl_stock_monthly_returns + 1).cumprod().plot()
plt.show()

# %% [markdown]
# ## statistical data
# ### calculating the Mean, Standard deviation and other stats

# %%
# mean
print(multpl_stock_monthly_returns.mean())

# %%
# std
print(multpl_stock_monthly_returns.std())

# %%
# correlation
print(multpl_stock_monthly_returns.corr())

# %%
# covariance
print(multpl_stock_monthly_returns.cov())

# %%
import csv

with open('T20'+str('a')+'_Sec'+str('a')+'_stdR.csv', 'w', encoding='utf-8', newline='') as f:
    csvwriter = csv.writer(f)
    csvwriter.writerow(['ticker','pc1','pc2','std_return'])
    for i in range(0,len(df)):
        for j in range(0,len(std_return.index)):
            if df['ticker'][i]==std_return.index.tolist()[j]:
                csvwriter.writerow([df['ticker'][i],df['pc1'][i],df['pc2'][i],std_return[j]])

# %% [markdown]
# # working space

# %%
# download from yahoo finance for each sector
yf.pdr_override() 

# change input&output data name
year=18    # 15-19  

for i in range(0,9):
    sec=1+i
    df=pd.read_csv('T20'+str(year)+'_Sec'+str(sec)+'.csv')   ## input dataset
    tickers=list(df.ticker)     

    daily_return = web.get_data_yahoo(tickers,start = "2017-12-31",end = "2018-3-31")['Adj Close']

    # save std_return to csv file
    std_return=daily_return.pct_change().std()
    
    
    with open('T20'+str(year)+'_Sec'+str(sec)+'_std.csv', 'w', encoding='utf-8', newline='') as f:
        csvwriter = csv.writer(f)
        csvwriter.writerow(['ticker','pc1','pc2','std'])
        for k in range(0,len(df)):
            for j in range(0,len(std_return.index)):
                if df['ticker'][k]==std_return.index.tolist()[j]:
                    csvwriter.writerow([df['ticker'][k],df['pc1'][k],df['pc2'][k],std_return[j]])
# Out:
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ROAD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'KZR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'MWK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'THMO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UBX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EXE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AMK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CCB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
# for single doc
yf.pdr_override() 

df=pd.read_csv('RFactors_2017.csv')   ## input dataset
tickers=list(df.ticker)     

daily_return = web.get_data_yahoo(tickers,start = "2016-12-31",end = "2017-3-31")['Adj Close']

    # save std_return to csv file
std_return=daily_return.pct_change().std()
    
    
with open('RFactors_2017std.csv', 'w', encoding='utf-8', newline='') as f:
    csvwriter = csv.writer(f)
    csvwriter.writerow(['ticker','SIC','pc1','pc2','std'])
    for k in range(0,len(df)):
        for j in range(0,len(std_return.index)):
            if df['ticker'][k]==std_return.index.tolist()[j]:
                csvwriter.writerow([df['ticker'][k],df['SIC'][k],df['pc1'][k],df['pc2'][k],std_return[j]])
# Out:
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AAAU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AANC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AAPC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ABEL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ABFF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ABS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ACA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ACAM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ACBM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ACEL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ACTT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ADIL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ADOM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ADPT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ADT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AEI20', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AEI21', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AEI22', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AEI24', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AEI25', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AEI26', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AESE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AFIN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AGBAU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AGGG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AGS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AIGT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AIHS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AJIA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AKCA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AKRO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALAC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALEC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALGR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALIC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALLK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALLO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALNA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALRN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALTM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ALTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AMRQQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AMRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ANCN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ANDAU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AOIP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APEVENT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APHB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APLS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APLT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APPN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APRE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APRN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'APYX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AQST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AQUA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ARCE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ARGX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ARLO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ARTL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ARVN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ASIQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ATCIIIX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ATIF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ATNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ATUS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ATXI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AUTL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AVL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AVLR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AVTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AVYA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AXAEQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AXNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'AXP/20', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BAND', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BBCP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BBIO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BCEL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BCOW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BCYC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BDTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BEDU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BFST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BHF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BHHV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BHVN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BILI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BION', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BIOX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BJ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BKGM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BLKE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BLYQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BNGO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BNTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BPI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BPMP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BRLL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BRMT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BRP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BRS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BSBK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BSVN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BTAI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BTU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BWAY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BWB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BXG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'BYND', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CABA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CADE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CARG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CARS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CASA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CASSIDY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CBMB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CBNK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CBNT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CBTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CCC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CCNI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CDAY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CDLX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CEC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CEIX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CELC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CFBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CFFA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CFT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CHGCH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CHRA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLDR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLDS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLJO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLNC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLPS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CLXT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CMBM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CMLS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CNL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CNNE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CNSP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CNST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CNTM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CODX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'COLD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CPLG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CPWR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CRDA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CRDXE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CRNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CRON', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CRSA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CRTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CSAF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CSGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CSTL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CTRM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CTVA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CUE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CURO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CVET', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CVIA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CVNA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CWK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CYCN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DAVA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DAVEY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DBX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DCPH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DDOG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DE22B', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DEAC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DELT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DEVV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DFBHU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DFODQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DGJI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DGSE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DHGC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DIVXZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DMTK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DNLI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DOCU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DOGZ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DOMO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DOW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DPDM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DPHC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DQWS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DSSI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DTIL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DWSF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'DWSX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EAF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ECOR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EEPL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EEX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EFBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EIDX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ELAN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ELVT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EOLS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EPAC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EPEG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EPRT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EQH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ERYP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ESQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ESTA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ESTC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ETNB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ETPPRC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ETRN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ETTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EVER', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EVLO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EVLV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EVOP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EXDW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EYE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'EYEN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FAMI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FCBP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FEDU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FENC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FES', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FFBW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FGNV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FHLBATL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FHLBBOST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'FHLBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRILINC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRKK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRMD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRMT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRNE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRTK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRTX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TRWH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TTS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TUFN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TWST', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TYGS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'TZACU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UBER', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UMRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UNMN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UPWK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'URGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'UROV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'URYL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'USOU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'USPB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'USWS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'USX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VAPO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VCBD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VCNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VCTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VDI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VERI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VERO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VERY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VIBI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VICI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VIE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VIEMF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VIR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VISI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VMCI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VNTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VRCP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VRNA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VSUL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'VVNT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WFTLF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WHD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WISA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WLMS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WLUC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WMG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WNCF', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WOW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WRLSU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WRTC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WTRE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WTRG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'WTTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XAIR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XCUR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XERS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XFOR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XGN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XTGR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'XTNY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'YEXT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'YMAB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'YTFD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'YZCM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZARTEX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZCOR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZETAI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZKIN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZNAVIX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/Polaris/anaconda3/lib/python3.7/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'ZYME', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
